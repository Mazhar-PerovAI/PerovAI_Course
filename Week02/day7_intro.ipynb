# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("jupyter notebook is working")
# Out:
# jupyter notebook is working

# %%
df = pd.DataFrame({"Name" : ["Mazhar", "John", "Ethan", "Sara"], "Age" : [40, 45, 50, 35]})
df
df
# Out:
#      Name  Age
# 0  Mazhar   40
# 1    John   45
# 2   Ethan   50
# 3    Sara   35

# %%
plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.title("Test plot")
plt.show()

# %%
df = pd.read_csv("sample_data.csv")
df
df.describe()
# Out:
#             Age  Temperature
# count   4.00000      4.00000
# mean   38.00000     66.50000
# std    22.55364      3.41565
# min    17.00000     62.00000
# 25%    23.00000     65.00000
# 50%    33.50000     67.00000
# 75%    48.50000     68.50000
# max    68.00000     70.00000

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("sample_data.csv")
plt.bar(df["Name"], df["Temperature"], color="green")
plt.title("Temperature by person")
plt.xlabel("Name")
plt.ylabel("Temperature")
plt.show()

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame        Name  Age         cit<...> los angeles           68
# np         module       <module 'numpy' from 'd:\<...>ges\\numpy\\__init__.py'>
# pd         module       <module 'pandas' from 'd:<...>es\\pandas\\__init__.py'>
# plt        module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>

# %%
# %time sum(range(1000000))
# Out:
# CPU times: total: 62.5 ms
# Wall time: 62.2 ms
# 499999500000

# %%
df = pd.read_csv("sample_data.csv")
df
# Out:
#     Name  Age         city  Temperature
# 0  Tanka   42      Seattle           66
# 1   John   17      Newyork           62
# 2    Ali   68      Karachi           70
# 3   Sara   25  los angeles           68

# %%
df.head
# Out:
# <bound method NDFrame.head of     Name  Age         city  Temperature
# 0  Tanka   42      Seattle           66
# 1   John   17      Newyork           62
# 2    Ali   68      Karachi           70
# 3   Sara   25  los angeles           68>

# %%
df.tail()
# Out:
#     Name  Age         city  Temperature
# 0  Tanka   42      Seattle           66
# 1   John   17      Newyork           62
# 2    Ali   68      Karachi           70
# 3   Sara   25  los angeles           68

# %%
df.describe()
# Out:
#             Age  Temperature
# count   4.00000      4.00000
# mean   38.00000     66.50000
# std    22.55364      3.41565
# min    17.00000     62.00000
# 25%    23.00000     65.00000
# 50%    33.50000     67.00000
# 75%    48.50000     68.50000
# max    68.00000     70.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         4 non-null      object
#  1   Age          4 non-null      int64
#  2   city         4 non-null      object
#  3   Temperature  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df = pd.read_csv("sample_data.csv")
plt.scatter(df["Age"], df["Temperature"])
plt.title("plot age vs temperature")
plt.xlabel("Age")
plt.ylabel("Temperature")
plt.show()

# %%
df =pd.DataFrame({"Materials" : ["Iron", "copper", "silver", "Gold", "Tin"], "Resistivity" : [20, 15, 7, 6, 25]})
plt.plot(df["Materials"], df["Resistivity"])
plt.title("Material property plot")
plt.xlabel("Materials")
plt.ylabel("Resistivity")
plt.show()
