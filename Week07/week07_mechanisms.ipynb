# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("../Week06/datasets/week06_device_features.csv")
df.head()
# Out:
#         Device  Voc_mean  Voc_max   Jsc_mean    Jsc_max   FF_mean    FF_std  \
# 0  device001_1  1.098735  1.14045  10.393274  19.918979  0.688449  0.038685
# 1  device001_2  1.082345  1.11065   9.770149  18.563928  0.667659  0.022543
# 2  device001_3  1.033197  1.11065  10.134377  19.455737  0.735948  0.208638
# 3  device001_4  1.040642  1.11065  10.035640  19.258098  0.682396  0.053346
# 4  device001_5  0.924470  1.11065  10.275039  20.005364  0.467460  0.290469
#
#    leakage_slope        J0
# 0      -0.005102  0.003786
# 1      -0.006520  0.004570
# 2      -0.004887  0.004208
# 3      -0.004235  0.004003
# 4      -7.885415 -0.057738

# %%
X = df.drop(columns=["Device"])
X = X.select_dtypes(include=[np.number])
X = X.fillna(X.median())

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df["Cluster"] = kmeans.fit_predict(X_scaled)
df[["Device","Cluster"]]
# Out:
# d:\Anaconda3\envs\perovAI\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#          Device  Cluster
# 0   device001_1        2
# 1   device001_2        2
# 2   device001_3        2
# 3   device001_4        2
# 4   device001_5        0
# 5   device001_6        2
# 6   device001_7        2
# 7   device003_1        1
# 8   device003_2        1
# 9   device003_3        1
# 10  device003_4        1
# 11  device003_5        1
# 12  device003_6        1
# 13  device003_7        2
# 14  device003_8        1
# 15  device004_1        1
# 16  device004_2        1
# 17  device004_3        1
# 18  device004_4        1
# 19  device004_5        1
# 20  device004_6        1
# 21  device004_7        1
# 22  device004_8        1

# %%
# make sure Cluster is numeric
df["Cluster"] = pd.to_numeric(df["Cluster"], errors="coerce")

# average ONLY numeric columns
cluster_means = df.groupby("Cluster").mean(numeric_only=True)
cluster_means
# Out:
#          Voc_mean   Voc_max   Jsc_mean    Jsc_max   FF_mean    FF_std  \
# Cluster
# 0        0.924470  1.110650  10.275039  20.005364  0.467460  0.290469
# 1        1.049873  1.108663  10.977152  22.154996  0.706393  0.046283
# 2        1.036176  1.114907  10.127737  19.569909  0.717958  0.216764
#
#          leakage_slope        J0
# Cluster
# 0            -7.885415 -0.057738
# 1            -0.370737  0.002800
# 2            -0.005839  0.004739

# %%
df.to_csv("week07_results.csv", index=False)
print("Saved → week07_results.csv")
# Out:
# Saved → week07_results.csv

# %%
df.groupby("Cluster").mean(numeric_only=True)
# Out:
#          Voc_mean   Voc_max   Jsc_mean    Jsc_max   FF_mean    FF_std  \
# Cluster
# 0        0.924470  1.110650  10.275039  20.005364  0.467460  0.290469
# 1        1.049873  1.108663  10.977152  22.154996  0.706393  0.046283
# 2        1.036176  1.114907  10.127737  19.569909  0.717958  0.216764
#
#          leakage_slope        J0
# Cluster
# 0            -7.885415 -0.057738
# 1            -0.370737  0.002800
# 2            -0.005839  0.004739

# %%
cluster_labels = {
    0: "Shunt limited",
    1: "Recombination limited",
    2: "Transport/interface limited"
}

df["Failure_Mode"] = df["Cluster"].map(cluster_labels)
df[["Device","Failure_Mode"]]
# Out:
#          Device                 Failure_Mode
# 0   device001_1  Transport/interface limited
# 1   device001_2  Transport/interface limited
# 2   device001_3  Transport/interface limited
# 3   device001_4  Transport/interface limited
# 4   device001_5                Shunt limited
# 5   device001_6  Transport/interface limited
# 6   device001_7  Transport/interface limited
# 7   device003_1        Recombination limited
# 8   device003_2        Recombination limited
# 9   device003_3        Recombination limited
# 10  device003_4        Recombination limited
# 11  device003_5        Recombination limited
# 12  device003_6        Recombination limited
# 13  device003_7  Transport/interface limited
# 14  device003_8        Recombination limited
# 15  device004_1        Recombination limited
# 16  device004_2        Recombination limited
# 17  device004_3        Recombination limited
# 18  device004_4        Recombination limited
# 19  device004_5        Recombination limited
# 20  device004_6        Recombination limited
# 21  device004_7        Recombination limited
# 22  device004_8        Recombination limited

# %%
cluster_labels = {
    0: "Shunt-limited",
    1: "Recombination-limited",
    2: "Transport/interface-limited"
}

df["Failure_Mode"] = df["Cluster"].map(cluster_labels)
df[["Device","Cluster","Failure_Mode"]]
# Out:
#          Device  Cluster                 Failure_Mode
# 0   device001_1        2  Transport/interface-limited
# 1   device001_2        2  Transport/interface-limited
# 2   device001_3        2  Transport/interface-limited
# 3   device001_4        2  Transport/interface-limited
# 4   device001_5        0                Shunt-limited
# 5   device001_6        2  Transport/interface-limited
# 6   device001_7        2  Transport/interface-limited
# 7   device003_1        1        Recombination-limited
# 8   device003_2        1        Recombination-limited
# 9   device003_3        1        Recombination-limited
# 10  device003_4        1        Recombination-limited
# 11  device003_5        1        Recombination-limited
# 12  device003_6        1        Recombination-limited
# 13  device003_7        2  Transport/interface-limited
# 14  device003_8        1        Recombination-limited
# 15  device004_1        1        Recombination-limited
# 16  device004_2        1        Recombination-limited
# 17  device004_3        1        Recombination-limited
# 18  device004_4        1        Recombination-limited
# 19  device004_5        1        Recombination-limited
# 20  device004_6        1        Recombination-limited
# 21  device004_7        1        Recombination-limited
# 22  device004_8        1        Recombination-limited

# %%
def suggest(row):
    if row["Failure_Mode"] == "Recombination-limited":
        return "Reduce traps, improve bulk and interface passivation, optimize crystallization."
    if row["Failure_Mode"] == "Shunt-limited":
        return "Improve film coverage, reduce pinholes, improve substrate cleaning."
    if row["Failure_Mode"] == "Transport/interface-limited":
        return "Improve contacts, tune ETL/HTL thickness, reduce interface barriers."
    return "Stable device"

df["Suggestion"] = df.apply(suggest, axis=1)
df[["Device","Failure_Mode","Suggestion"]]
# Out:
#          Device                 Failure_Mode  \
# 0   device001_1  Transport/interface-limited
# 1   device001_2  Transport/interface-limited
# 2   device001_3  Transport/interface-limited
# 3   device001_4  Transport/interface-limited
# 4   device001_5                Shunt-limited
# 5   device001_6  Transport/interface-limited
# 6   device001_7  Transport/interface-limited
# 7   device003_1        Recombination-limited
# 8   device003_2        Recombination-limited
# 9   device003_3        Recombination-limited
# 10  device003_4        Recombination-limited
# 11  device003_5        Recombination-limited
# 12  device003_6        Recombination-limited
# 13  device003_7  Transport/interface-limited
# 14  device003_8        Recombination-limited
# 15  device004_1        Recombination-limited
# 16  device004_2        Recombination-limited
# 17  device004_3        Recombination-limited
# 18  device004_4        Recombination-limited
# 19  device004_5        Recombination-limited
# 20  device004_6        Recombination-limited
# 21  device004_7        Recombination-limited
# 22  device004_8        Recombination-limited
#
#                                            Suggestion
# 0   Improve contacts, tune ETL/HTL thickness, redu...
# 1   Improve contacts, tune ETL/HTL thickness, redu...
# 2   Improve contacts, tune ETL/HTL thickness, redu...
# 3   Improve contacts, tune ETL/HTL thickness, redu...
# 4   Improve film coverage, reduce pinholes, improv...
# 5   Improve contacts, tune ETL/HTL thickness, redu...
# 6   Improve contacts, tune ETL/HTL thickness, redu...
# 7   Reduce traps, improve bulk and interface passi...
# 8   Reduce traps, improve bulk and interface passi...
# 9   Reduce traps, improve bulk and interface passi...
# 10  Reduce traps, improve bulk and interface passi...
# 11  Reduce traps, improve bulk and interface passi...
# 12  Reduce traps, improve bulk and interface passi...
# 13  Improve contacts, tune ETL/HTL thickness, redu...
# 14  Reduce traps, improve bulk and interface passi...
# 15  Reduce traps, improve bulk and interface passi...
# 16  Reduce traps, improve bulk and interface passi...
# 17  Reduce traps, improve bulk and interface passi...
# 18  Reduce traps, improve bulk and interface passi...
# 19  Reduce traps, improve bulk and interface passi...
# 20  Reduce traps, improve bulk and interface passi...
# 21  Reduce traps, improve bulk and interface passi...
# 22  Reduce traps, improve bulk and interface passi...

# %%
df.to_csv("week07_with_guidance.csv", index=False)
print("Saved → week07_with_guidance.csv")
# Out:
# Saved → week07_with_guidance.csv

# %%
df.groupby("Failure_Mode").mean(numeric_only=True)
# Out:
#                              Voc_mean   Voc_max   Jsc_mean    Jsc_max  \
# Failure_Mode
# Recombination-limited        1.049873  1.108663  10.977152  22.154996
# Shunt-limited                0.924470  1.110650  10.275039  20.005364
# Transport/interface-limited  1.036176  1.114907  10.127737  19.569909
#
#                               FF_mean    FF_std  leakage_slope        J0  \
# Failure_Mode
# Recombination-limited        0.706393  0.046283      -0.370737  0.002800
# Shunt-limited                0.467460  0.290469      -7.885415 -0.057738
# Transport/interface-limited  0.717958  0.216764      -0.005839  0.004739
#
#                              Cluster
# Failure_Mode
# Recombination-limited            1.0
# Shunt-limited                    0.0
# Transport/interface-limited      2.0

# %%
df["Risk"] = df[["J0","leakage_slope","FF_std"]].rank(pct=True).mean(axis=1)
df.sort_values("Risk", ascending=False)[["Device","Failure_Mode","Risk","Suggestion"]].head(10)
# Out:
#          Device                 Failure_Mode      Risk  \
# 13  device003_7  Transport/interface-limited  0.768116
# 14  device003_8        Recombination-limited  0.681159
# 12  device003_6        Recombination-limited  0.666667
# 17  device004_3        Recombination-limited  0.652174
# 2   device001_3  Transport/interface-limited  0.652174
# 18  device004_4        Recombination-limited  0.637681
# 5   device001_6  Transport/interface-limited  0.623188
# 3   device001_4  Transport/interface-limited  0.623188
# 11  device003_5        Recombination-limited  0.608696
# 7   device003_1        Recombination-limited  0.594203
#
#                                            Suggestion
# 13  Improve contacts, tune ETL/HTL thickness, redu...
# 14  Reduce traps, improve bulk and interface passi...
# 12  Reduce traps, improve bulk and interface passi...
# 17  Reduce traps, improve bulk and interface passi...
# 2   Improve contacts, tune ETL/HTL thickness, redu...
# 18  Reduce traps, improve bulk and interface passi...
# 5   Improve contacts, tune ETL/HTL thickness, redu...
# 3   Improve contacts, tune ETL/HTL thickness, redu...
# 11  Reduce traps, improve bulk and interface passi...
# 7   Reduce traps, improve bulk and interface passi...

# %%
df[["Device","Failure_Mode","Risk","Suggestion"]].sort_values("Risk", ascending=False)\
  .to_csv("perovai_lab_report.csv", index=False)

print("Saved → perovai_lab_report.csv")
# Out:
# Saved → perovai_lab_report.csv
