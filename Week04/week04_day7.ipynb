# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/perovai_devices_day6_stability_ready.csv")
df.head()
# Out:
#       Device  FF_Forward  FF_Reverse  Jsc_mAcm2_Forward  Jsc_mAcm2_Reverse  \
# 0  device001    0.650051    0.640161          20.177047          20.178596
# 1  device002    0.746704    0.758766          20.051937          20.154208
# 2  device003    0.771115    0.767192          20.756446          20.797109
# 3  device004    0.748184    0.759476          20.071712          20.171704
# 4  device005    0.748388    0.755708          20.152430          20.259536
#
#    PCE_percent_Forward  PCE_percent_Reverse  Rs_ohm_cm2_Forward  \
# 0            14.491762            14.377952            8.245944
# 1            17.134683            17.777031            6.118376
# 2            18.363962            18.387340            4.786209
# 3            17.191299            17.810883            6.110401
# 4            17.333143            17.911775            6.452673
#
#    Rs_ohm_cm2_Reverse  Rsh_ohm_cm2_Forward  ...  Voc_V_Forward  Voc_V_Reverse  \
# 0            8.304344          5106.928620  ...       1.104883       1.113055
# 1            7.594258          3341.636255  ...       1.144383       1.162480
# 2            5.584745          4110.186343  ...       1.147345       1.152423
# 3            7.581881          3240.772843  ...       1.144763       1.162596
# 4            8.205573          3485.020804  ...       1.149273       1.169918
#
#    Delta_PCE  Delta_Voc  Delta_Jsc  Delta_FF  Hysteresis_Index  \
# 0  -0.113810   0.008172   0.001549 -0.009890         -0.007916
# 1   0.642347   0.018098   0.102270  0.012062          0.036134
# 2   0.023378   0.005078   0.040663 -0.003923          0.001271
# 3   0.619584   0.017833   0.099991  0.011292          0.034787
# 4   0.578632   0.020645   0.107106  0.007320          0.032305
#
#    High_Hysteresis  Low_Rs  Unstable
# 0                0       1         0
# 1                0       1         0
# 2                0       1         0
# 3                0       1         0
# 4                0       1         0
#
# [5 rows x 21 columns]

# %%
# Normalize key instability drivers
df["norm_Delta_PCE"] = (df["Delta_PCE"] - df["Delta_PCE"].mean()) / df["Delta_PCE"].std()
df["norm_Hysteresis"] = (df["Hysteresis_Index"] - df["Hysteresis_Index"].mean()) / df["Hysteresis_Index"].std()
df["norm_Rs"] = (df["Rs_ohm_cm2_Reverse"] - df["Rs_ohm_cm2_Reverse"].mean()) / df["Rs_ohm_cm2_Reverse"].std()

# Weighted risk score (based on Day‑6 coefficients qualitatively)
df["Risk_Score"] = (
    0.5 * df["norm_Delta_PCE"] +
    0.3 * df["norm_Hysteresis"] +
    0.2 * df["norm_Rs"]
)

df[["Device","Risk_Score"]].head()
# Out:
#       Device  Risk_Score
# 0  device001   -0.520716
# 1  device002    0.291022
# 2  device003   -0.373442
# 3  device004    0.266586
# 4  device005    0.222623

# %%
df = df.sort_values("Risk_Score", ascending=False)
df[["Device","Risk_Score"]].head(15)
# Out:
#        Device  Risk_Score
# 86  device087    2.794526
# 41  device042    2.204792
# 47  device048    1.155777
# 44  device045    0.958746
# 25  device026    0.814790
# 45  device046    0.809948
# 87  device088    0.777767
# 23  device024    0.759765
# 83  device084    0.706719
# 21  device022    0.705775
# 97  device098    0.671871
# 69  device070    0.649978
# 72  device073    0.609192
# 77  device078    0.607659
# 91  device092    0.579179

# %%
q1 = df["Risk_Score"].quantile(0.33)
q2 = df["Risk_Score"].quantile(0.66)

def risk_label(x):
    if x > q2:
        return "High Risk"
    elif x > q1:
        return "Medium Risk"
    else:
        return "Low Risk"

df["Risk_Category"] = df["Risk_Score"].apply(risk_label)
df["Risk_Category"].value_counts()
# Out:
# Risk_Category
# High Risk      36
# Medium Risk    35
# Low Risk       35
# Name: count, dtype: int64

# %%
def recommendation(row):
    if row["Risk_Category"] == "High Risk":
        if row["Hysteresis_Index"] > 0.05:
            return "Reduce ionic migration / improve interface passivation"
        elif row["Rs_ohm_cm2_Reverse"] > df["Rs_ohm_cm2_Reverse"].median():
            return "Improve charge transport / contacts"
        else:
            return "General stability optimization needed"
    elif row["Risk_Category"] == "Medium Risk":
        return "Monitor stability, optimize interfaces"
    else:
        return "Device appears stable"

df["Recommendation"] = df.apply(recommendation, axis=1)

# %%
df[[
    "Device",
    "Risk_Category",
    "Risk_Score",
    "Hysteresis_Index",
    "Rs_ohm_cm2_Reverse",
    "Delta_PCE",
    "Recommendation"
]].head(20)
# Out:
#        Device Risk_Category  Risk_Score  Hysteresis_Index  Rs_ohm_cm2_Reverse  \
# 86  device087     High Risk    2.794526       1810.071312        8.914104e+07
# 41  device042     High Risk    2.204792          0.211110        1.045415e+01
# 47  device048     High Risk    1.155777          0.907055        1.458819e+09
# 44  device045     High Risk    0.958746          0.135702        1.231424e+01
# 25  device026     High Risk    0.814790          0.178794        1.461828e+01
# 45  device046     High Risk    0.809948          0.100393        9.313728e+00
# 87  device088     High Risk    0.777767          0.216026        5.879503e+01
# 23  device024     High Risk    0.759765          0.175148        1.580237e+01
# 83  device084     High Risk    0.706719          0.250471        3.545254e+01
# 21  device022     High Risk    0.705775          0.173126        1.511822e+01
# 97  device098     High Risk    0.671871          0.244700        2.285599e+01
# 69  device070     High Risk    0.649978          0.218442        2.161190e+01
# 72  device073     High Risk    0.609192          0.211739        2.750864e+01
# 77  device078     High Risk    0.607659          0.214112        2.473517e+01
# 91  device092     High Risk    0.579179          0.273335        4.617755e+01
# 55  device056     High Risk    0.550491          0.135099        8.178894e+00
# 81  device082     High Risk    0.458641          0.733888        8.041407e+08
# 76  device077     High Risk    0.453770          0.194364        3.047360e+01
# 42  device043     High Risk    0.378311          0.414004        1.702347e+01
# 70  device071     High Risk    0.367266          0.334370        3.398365e+01
#
#     Delta_PCE                                     Recommendation
# 86   0.008557  Reduce ionic migration / improve interface pas...
# 41   2.424966  Reduce ionic migration / improve interface pas...
# 47   0.000005  Reduce ionic migration / improve interface pas...
# 44   1.264251  Reduce ionic migration / improve interface pas...
# 25   1.130071  Reduce ionic migration / improve interface pas...
# 45   1.125685  Reduce ionic migration / improve interface pas...
# 87   1.095520  Reduce ionic migration / improve interface pas...
# 23   1.078815  Reduce ionic migration / improve interface pas...
# 83   1.029276  Reduce ionic migration / improve interface pas...
# 21   1.028520  Reduce ionic migration / improve interface pas...
# 97   0.996820  Reduce ionic migration / improve interface pas...
# 69   0.976466  Reduce ionic migration / improve interface pas...
# 72   0.938480  Reduce ionic migration / improve interface pas...
# 77   0.937048  Reduce ionic migration / improve interface pas...
# 91   0.910422  Reduce ionic migration / improve interface pas...
# 55   0.883915  Reduce ionic migration / improve interface pas...
# 81   0.000002  Reduce ionic migration / improve interface pas...
# 76   0.793714  Reduce ionic migration / improve interface pas...
# 42   0.723066  Reduce ionic migration / improve interface pas...
# 70   0.712904  Reduce ionic migration / improve interface pas...

# %%
df.to_csv("datasets/perovai_devices_day7_ranked_recommendations.csv", index=False)
print("Saved: datasets/perovai_devices_day7_ranked_recommendations.csv")
# Out:
# Saved: datasets/perovai_devices_day7_ranked_recommendations.csv
