# 19  deviceJ_LIV2  Forward
# 20  deviceK_LIV1  Reverse
# 21  deviceK_LIV2  Forward
# 22  deviceL_LIV1  Reverse
# 23  deviceL_LIV2  Forward

# %%
print("Total rows:", len(df))
print(df["Scan"].value_counts())
print(df["Device_ID"].nunique())
# Out:
# Total rows: 24
# Scan
# Reverse    12
# Forward    12
# Name: count, dtype: int64
# 24

# %%
# Clean column names
df.columns = df.columns.str.strip()

# FORCE correct device identifier (strip LIV info)
if "Device_ID" in df.columns:
    df["Device"] = df["Device_ID"].str.split("_").str[0]
elif "File" in df.columns:
    df["Device"] = df["File"].str.split("_").str[0]
else:
    raise ValueError("No usable device identifier found")

# %%
print("Unique devices:", df["Device"].nunique())
print(df[["Device", "Scan"]].head(10))
# Out:
# Unique devices: 12
#     Device     Scan
# 0  deviceA  Reverse
# 1  deviceA  Forward
# 2  deviceB  Reverse
# 3  deviceB  Forward
# 4  deviceC  Reverse
# 5  deviceC  Forward
# 6  deviceD  Reverse
# 7  deviceD  Forward
# 8  deviceE  Reverse
# 9  deviceE  Forward

# %%
pivot = df.pivot_table(
    index="Device",
    columns="Scan",
    values=[
        "Voc_V",
        "Jsc_mAcm2",
        "FF",
        "PCE_percent",
        "Rs_ohm_cm2",
        "Rsh_ohm_cm2"
    ]
)

pivot
# Out:
#                 FF            Jsc_mAcm2            PCE_percent             \
# Scan       Forward   Reverse    Forward    Reverse     Forward    Reverse
# Device
# deviceA   0.650051  0.640161  20.177047  20.178596   14.491762  14.377952
# deviceB   0.746704  0.758766  20.051937  20.154208   17.134683  17.777031
# deviceC   0.771115  0.767192  20.756446  20.797109   18.363962  18.387340
# deviceD   0.748184  0.759476  20.071712  20.171704   17.191299  17.810883
# deviceE   0.748388  0.755708  20.152430  20.259536   17.333143  17.911775
# deviceF   0.742607  0.756005  20.177981  20.284417   17.413985  18.007850
# deviceG   0.577113  0.575716  20.610881  20.646096   13.368269  13.462811
# deviceH  11.084178 -0.606497  -0.000005  -0.000019    0.000010   0.000014
# deviceI   0.771115  0.767192  20.756446  20.797109   18.363962  18.387340
# deviceJ   0.507957  0.541720   0.008112   0.008918    0.002806   0.003305
# deviceK   0.763795  0.735251  21.106099  21.114734   17.738648  17.077048
# deviceL   0.447154  0.467494   0.007515   0.008209    0.002294   0.002698
#
#            Rs_ohm_cm2                  Rsh_ohm_cm2                   Voc_V  \
# Scan          Forward       Reverse        Forward       Reverse   Forward
# Device
# deviceA  8.245944e+00  8.304344e+00    5106.928620  4.474455e+03  1.104883
# deviceB  6.118376e+00  7.594258e+00    3341.636255  7.605397e+03  1.144383
# deviceC  4.786209e+00  5.584745e+00    4110.186343  8.414256e+03  1.147345
# deviceD  6.110401e+00  7.581881e+00    3240.772843  7.279253e+03  1.144763
# deviceE  6.452673e+00  8.205573e+00    3485.020804  8.596770e+03  1.149273
# deviceF  7.284038e+00  5.459521e+00    2943.656033  5.343602e+03  1.162148
# deviceG  9.684322e+00  1.050184e+01    2185.467119  3.633686e+03  1.123873
# deviceH  2.750203e+08  2.026717e+08  900039.688878  2.381029e+06 -0.169800
# deviceI  4.786209e+00  5.584745e+00    4110.186343  8.414256e+03  1.147345
# deviceJ  2.610375e+04  1.571928e+04  309545.564228  3.474437e+05  0.680967
# deviceK  6.579598e+00  6.885309e+00    8792.643961  6.698656e+03  1.100362
# deviceL  2.672549e+04  2.767340e+04  292597.058659  3.159329e+05  0.682581
#
#
# Scan      Reverse
# Device
# deviceA  1.113055
# deviceB  1.162480
# deviceC  1.152423
# deviceD  1.162596
# deviceE  1.169918
# deviceF  1.174287
# deviceG  1.132634
# deviceH  1.219800
# deviceI  1.152423
# deviceJ  0.684069
# deviceK  1.099998
# deviceL  0.703010

# %%
pivot.columns = [
    f"{param}_{scan}"
    for param, scan in pivot.columns
]

pivot = pivot.reset_index()
pivot
# Out:
#      Device  FF_Forward  FF_Reverse  Jsc_mAcm2_Forward  Jsc_mAcm2_Reverse  \
# 0   deviceA    0.650051    0.640161          20.177047          20.178596
# 1   deviceB    0.746704    0.758766          20.051937          20.154208
# 2   deviceC    0.771115    0.767192          20.756446          20.797109
# 3   deviceD    0.748184    0.759476          20.071712          20.171704
# 4   deviceE    0.748388    0.755708          20.152430          20.259536
# 5   deviceF    0.742607    0.756005          20.177981          20.284417
# 6   deviceG    0.577113    0.575716          20.610881          20.646096
# 7   deviceH   11.084178   -0.606497          -0.000005          -0.000019
# 8   deviceI    0.771115    0.767192          20.756446          20.797109
# 9   deviceJ    0.507957    0.541720           0.008112           0.008918
# 10  deviceK    0.763795    0.735251          21.106099          21.114734
# 11  deviceL    0.447154    0.467494           0.007515           0.008209
#
#     PCE_percent_Forward  PCE_percent_Reverse  Rs_ohm_cm2_Forward  \
# 0             14.491762            14.377952        8.245944e+00
# 1             17.134683            17.777031        6.118376e+00
# 2             18.363962            18.387340        4.786209e+00
# 3             17.191299            17.810883        6.110401e+00
# 4             17.333143            17.911775        6.452673e+00
# 5             17.413985            18.007850        7.284038e+00
# 6             13.368269            13.462811        9.684322e+00
# 7              0.000010             0.000014        2.750203e+08
# 8             18.363962            18.387340        4.786209e+00
# 9              0.002806             0.003305        2.610375e+04
# 10            17.738648            17.077048        6.579598e+00
# 11             0.002294             0.002698        2.672549e+04
#
#     Rs_ohm_cm2_Reverse  Rsh_ohm_cm2_Forward  Rsh_ohm_cm2_Reverse  \
# 0         8.304344e+00          5106.928620         4.474455e+03
# 1         7.594258e+00          3341.636255         7.605397e+03
# 2         5.584745e+00          4110.186343         8.414256e+03
# 3         7.581881e+00          3240.772843         7.279253e+03
# 4         8.205573e+00          3485.020804         8.596770e+03
# 5         5.459521e+00          2943.656033         5.343602e+03
# 6         1.050184e+01          2185.467119         3.633686e+03
# 7         2.026717e+08        900039.688878         2.381029e+06
# 8         5.584745e+00          4110.186343         8.414256e+03
# 9         1.571928e+04        309545.564228         3.474437e+05
# 10        6.885309e+00          8792.643961         6.698656e+03
# 11        2.767340e+04        292597.058659         3.159329e+05
#
#     Voc_V_Forward  Voc_V_Reverse
# 0        1.104883       1.113055
# 1        1.144383       1.162480
# 2        1.147345       1.152423
# 3        1.144763       1.162596
# 4        1.149273       1.169918
# 5        1.162148       1.174287
# 6        1.123873       1.132634
# 7       -0.169800       1.219800
# 8        1.147345       1.152423
# 9        0.680967       0.684069
# 10       1.100362       1.099998
# 11       0.682581       0.703010

# %%
pivot["Delta_PCE"] = pivot["PCE_percent_Reverse"] - pivot["PCE_percent_Forward"]
pivot["Delta_Voc"] = pivot["Voc_V_Reverse"] - pivot["Voc_V_Forward"]
pivot["Delta_Jsc"] = pivot["Jsc_mAcm2_Reverse"] - pivot["Jsc_mAcm2_Forward"]
pivot["Delta_FF"]  = pivot["FF_Reverse"] - pivot["FF_Forward"]

pivot["Hysteresis_Index"] = (
    pivot["Delta_PCE"] / pivot["PCE_percent_Reverse"]
)

# %%
pivot_sorted = pivot.sort_values(
    "Hysteresis_Index",
    key=np.abs,
    ascending=False
)

pivot_sorted[[
    "Device",
    "PCE_percent_Reverse",
    "PCE_percent_Forward",
    "Delta_PCE",
    "Hysteresis_Index"
]]
# Out:
#      Device  PCE_percent_Reverse  PCE_percent_Forward  Delta_PCE  \
# 7   deviceH             0.000014             0.000010   0.000005
# 9   deviceJ             0.003305             0.002806   0.000499
# 11  deviceL             0.002698             0.002294   0.000404
# 10  deviceK            17.077048            17.738648  -0.661599
# 1   deviceB            17.777031            17.134683   0.642347
# 3   deviceD            17.810883            17.191299   0.619584
# 5   deviceF            18.007850            17.413985   0.593865
# 4   deviceE            17.911775            17.333143   0.578632
# 0   deviceA            14.377952            14.491762  -0.113810
# 6   deviceG            13.462811            13.368269   0.094542
# 2   deviceC            18.387340            18.363962   0.023378
# 8   deviceI            18.387340            18.363962   0.023378
#
#     Hysteresis_Index
# 7           0.337591
# 9           0.150891
# 11          0.149803
# 10         -0.038742
# 1           0.036134
# 3           0.034787
# 5           0.032978
# 4           0.032305
# 0          -0.007916
# 6           0.007022
# 2           0.001271
# 8           0.001271

# %%
pivot["High_Hysteresis"] = (
    pivot["Hysteresis_Index"].abs() > 0.05
).astype(int)

pivot["Low_Rs"] = (
    pivot["Rs_ohm_cm2_Reverse"] <
    pivot["Rs_ohm_cm2_Reverse"].median()
).astype(int)

# %%
pivot.to_csv(
    "datasets/perovai_devices_day5_hysteresis.csv",
    index=False
)
